# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
muqtar=pd.read_excel('pastor john data.xlsx')
muqtar
# Out:
#     Year  Population_Total  Population_Growth_rate    Total_GDP   \
# 0   1982         77427.539                2.633909  1.498508e+07
# 1   1983         79414.841                2.566660  1.384973e+07
# 2   1984         81448.757                2.561128  1.377926e+07
# 3   1985         83562.776                2.595520  1.495391e+07
# 4   1986         85766.396                2.637083  1.523799e+07
# 5   1987         88048.029                2.660288  1.526393e+07
# 6   1988         90395.278                2.665873  1.621537e+07
# 7   1989         92788.039                2.646998  1.729468e+07
# 8   1990         95212.454                2.612853  1.930563e+07
# 9   1991         97667.632                2.578631  1.919906e+07
# 10  1992        100161.708                2.553636  1.962019e+07
# 11  1993        102700.751                2.534944  1.992799e+07
# 12  1994        105293.701                2.524762  1.997912e+07
# ...

# %%
muqtar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    38 non-null     int64
#  1   Population_Total        38 non-null     float64
#  2   Population_Growth_rate  38 non-null     float64
#  3   Total_GDP               38 non-null     float64
#  4   GDP_Growth_rate         38 non-null     float64
# dtypes: float64(4), int64(1)
# memory usage: 1.6 KB

# %%
muqtar.describe()
# Out:
#               Year  Population_Total  Population_Growth_rate    Total_GDP   \
# count    38.000000         38.000000               38.000000  3.800000e+01
# mean   2000.500000     129339.275132                2.611915  1.813884e+07
# std      11.113055      36778.039617                0.066050  1.408128e+07
# min    1982.000000      77427.539000                2.520021  5.546935e+04
# 25%    1991.250000      98291.151000                2.553591  3.498884e+06
# 50%    2000.500000     123838.949500                2.616131  1.925235e+07
# 75%    2009.750000     157458.637000                2.665031  2.337856e+07
# max    2019.000000     200963.603000                2.717190  4.985610e+07
#
#        GDP_Growth_rate
# count        38.000000
# mean          1.337542
# std          17.394263
# min         -99.888741
# 25%           0.996617
# 50%           3.468975
# 75%           6.711193
# max          14.604381

# %%
muqtar.set_index(['Year'])
# Out:
#       Population_Total  Population_Growth_rate    Total_GDP   GDP_Growth_rate
# Year
# 1982         77427.539                2.633909  1.498508e+07        -1.788740
# 1983         79414.841                2.566660  1.384973e+07        -7.576558
# 1984         81448.757                2.561128  1.377926e+07        -0.508816
# 1985         83562.776                2.595520  1.495391e+07         8.524826
# 1986         85766.396                2.637083  1.523799e+07         1.899665
# 1987         88048.029                2.660288  1.526393e+07         0.170244
# 1988         90395.278                2.665873  1.621537e+07         6.233269
# 1989         92788.039                2.646998  1.729468e+07         6.656061
# 1990         95212.454                2.612853  1.930563e+07        11.627609
# 1991         97667.632                2.578631  1.919906e+07        -0.552030
# 1992        100161.708                2.553636  1.962019e+07         2.193493
# ...

# %%
muqtarcon=pd.concat([muqtar['Population_Total']],axis=1)
muqtarcon.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='Population_Total', y='Year', data=muqtar, orient='h')
### 2019 has the highest Population_Total and 1982 has the lowest Population_Total
# Out:
# <AxesSubplot:xlabel='Population_Total', ylabel='Year'>

# %%
sns.barplot(x='Population_Growth_rate', y='Year', data=muqtar, orient='h')
# Out:
# <AxesSubplot:xlabel='Population_Growth_rate', ylabel='Year'>
